# %%
import pandas as pd

df = pd.read_csv("Data101.csv")
df.head()
# Out:
#   STATENAME  VE_TOTAL  PERSONS     FUNC_SYSNAME           HARM_EVNAME  \
# 0   Alabama         1        1  Major Collector     Rollover/Overturn
# 1   Alabama         1        1            Local  Tree (Standing Only)
# 2   Alabama         1        1  Major Collector            Embankment
# 3   Alabama         1        3            Local           Live Animal
# 4   Alabama         1        4       Interstate  Tree (Standing Only)
#
#                                         MAN_COLLNAME REL_ROADNAME  \
# 0  The First Harmful Event was Not a Collision wi...  On Roadside
# 1  The First Harmful Event was Not a Collision wi...  On Roadside
# 2  The First Harmful Event was Not a Collision wi...  On Roadside
# 3  The First Harmful Event was Not a Collision wi...  On Roadside
# 4  The First Harmful Event was Not a Collision wi...  On Roadside
#
#          LGT_CONDNAME WEATHERNAME  FATALS
# 0  Dark - Not Lighted       Clear       1
# 1  Dark - Not Lighted       Clear       1
# ...

# %%
df.isnull().sum()
# Out:
# STATENAME       0
# VE_TOTAL        0
# PERSONS         0
# FUNC_SYSNAME    0
# HARM_EVNAME     0
# MAN_COLLNAME    0
# REL_ROADNAME    0
# LGT_CONDNAME    0
# WEATHERNAME     0
# FATALS          0
# dtype: int64

# %%
df = df.replace(["Unknown", "?" , "N/A"], pd.NA)

# %%
df = df.dropna()
df.head()
# Out:
#   STATENAME  VE_TOTAL  PERSONS     FUNC_SYSNAME           HARM_EVNAME  \
# 0   Alabama         1        1  Major Collector     Rollover/Overturn
# 1   Alabama         1        1            Local  Tree (Standing Only)
# 2   Alabama         1        1  Major Collector            Embankment
# 3   Alabama         1        3            Local           Live Animal
# 4   Alabama         1        4       Interstate  Tree (Standing Only)
#
#                                         MAN_COLLNAME REL_ROADNAME  \
# 0  The First Harmful Event was Not a Collision wi...  On Roadside
# 1  The First Harmful Event was Not a Collision wi...  On Roadside
# 2  The First Harmful Event was Not a Collision wi...  On Roadside
# 3  The First Harmful Event was Not a Collision wi...  On Roadside
# 4  The First Harmful Event was Not a Collision wi...  On Roadside
#
#          LGT_CONDNAME WEATHERNAME  FATALS
# 0  Dark - Not Lighted       Clear       1
# 1  Dark - Not Lighted       Clear       1
# ...
